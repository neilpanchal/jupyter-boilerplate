# %% [markdown]
# # Notebook Title

# %% [markdown]
# Author: Neil Panchal
#
# Date:
#
# Description:

# %%
# Check system version
import sys
print(sys.version)
# Out:
# 3.5.3 |Continuum Analytics, Inc.| (default, Mar  6 2017, 12:15:08)
# [GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.57)]

# %%
# Import Core libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import seaborn as sns

# Graphics
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
mpl.rcParams['figure.figsize'] = (8,8)
mpl.rcParams['font.family'] = 'SF Mono'
mpl.rcParams.update({'font.size': 12})

# Seaborn settings
sns.set(font_scale = 1.25)
sns.set_style('ticks', {'font.family' : 'SF Mono', 
                        'axes.grid' : True, 
                        'grid.linestyle': 'dotted',
                        'grid.color': '0.8'})
sns.axes_style({'axes.grid' : 'True'})
sns.set_palette(sns.color_palette(['Black']))

# %%
X = 2 * np.random.rand(100, 1) # 100 points
y = 4 + 3 * X + np.random.rand(100, 1) # y is a function of x
df = pd.DataFrame(np.c_[X, y], columns = ['X', 'y'])
g = sns.regplot(data = df, x = 'X', y = 'y', fit_reg = False, scatter = True, scatter_kws = dict(s = 20))

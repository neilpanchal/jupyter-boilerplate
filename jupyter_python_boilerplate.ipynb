# %% [markdown]
# # Notebook Title

# %% [markdown]
# Author: Neil Panchal
#
# Date:
#
# Description:

# %%
# Check system version
import sys
print(sys.version)
# Out:
# 3.6.4 |Anaconda, Inc.| (default, Jan 16 2018, 12:04:33)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
# Import Core libraries
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import seaborn as sns

# Graphics
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['font.family'] = 'SF Mono'
mpl.rcParams.update({'font.size': 12})
mpl.rcParams['axes.titlepad'] = 20 
mpl.rcParams['axes.titlesize'] = 12
mpl.rcParams['axes.labelpad'] = 10

# Seaborn settings
sns.set(font_scale = 1.25)
sns.set_style('ticks', {'font.family' : 'SF Mono', 
                        'axes.grid' : True, 
                        'grid.linestyle': 'dotted',
                        'grid.color': '0.8'})
sns.axes_style({'axes.grid' : 'True'})
sns.set_palette(sns.color_palette(['Black']))

# %%
# MPL Plot 
X = 2 * np.random.rand(100, 1) # 100 points
y = 4 + 3 * X + np.random.rand(100, 1) # y is a function of x
df = pd.DataFrame(np.c_[X, y], columns = ['X', 'y'])
plt.grid(color='#CCCCCC', linestyle='dotted')
plt.title('Figure 1. Random Distribution')
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.tight_layout()
plt.plot(X, y, '.', color='k');

# %%
# Seaborn Plot
X = 2 * np.random.rand(100, 1) # 100 points
y = 4 + 3 * X + np.random.rand(100, 1) # y is a function of x
df = pd.DataFrame(np.c_[X, y], columns = ['X', 'y'])
g = sns.regplot(data = df, 
                x = 'X', 
                y = 'y', 
                fit_reg = False, 
                scatter = True, 
                scatter_kws = dict(s = 20))
g.set_title('Figure 1. Regression Plot')
# Out:
# Text(0.5,1,'Figure 1. Regression Plot')
